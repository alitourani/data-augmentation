# %%
import imageio
import imgaug as ia
# %matplotlib inline

# Step1: Load the image
image = imageio.imread("E:/Datasets/Dataset 9 - the Cars (Stanford)/Train/00001.jpg")
print("Original Image:")
ia.imshow(image)
# Out:
# Original Image:

# %%
# Step2: Augmentation techniques

import numpy as np

images = [image, image, image, image]

seq = iaa.Sequential([
    iaa.Affine(rotate=(-10, 10)),
    iaa.AdditiveGaussianNoise(scale=(10, 60)),
    iaa.Crop(percent=(0, 0.2))
])

images_aug = seq(images=images)

print("Augmented Images:")
ia.imshow(np.hstack(images_aug))
# Out:
# Augmented Images:
